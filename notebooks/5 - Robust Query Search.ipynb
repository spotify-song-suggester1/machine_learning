# %%
import requests
import base64
import datetime
from urllib.parse import urlencode

# %%
client_id = '18bf732ea7ab485e91a45dfe7b75d5ec'
client_secret = '61d0f5271ab34e7aa519f1bebd81d3c9'

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"
    
    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret

    def get_client_credentials(self):
        """
        Returns a base64 encoded string
        """
        client_id = self.client_id
        client_secret = self.client_secret
        if client_secret == None or client_id == None:
            raise Exception("You must set client_id and client_secret")
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
    
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        return {
            "Authorization": f"Basic {client_creds_b64}"
        }
    
    def get_token_data(self):
        return {
            "grant_type": "client_credentials"
        } 
    
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url, data=token_data, headers=token_headers)
        if r.status_code not in range(200, 299):
            raise Exception("Could not authenticate client.")
            # return False
        data = r.json()
        now = datetime.datetime.now()
        access_token = data['access_token']
        expires_in = data['expires_in'] # seconds
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True
    
    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token() 
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization": f"Bearer {access_token}"
        }
        return headers
        
        
    def get_resource(self, lookup_id, resource_type='albums', version='v1'):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{lookup_id}"
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()
    
    def get_album(self, _id):
        return self.get_resource(_id, resource_type='albums')
    
    def get_artist(self, _id):
        return self.get_resource(_id, resource_type='artists')
    
    def base_search(self, query_params): # type
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        lookup_url = f"{endpoint}?{query_params}"
        r = requests.get(lookup_url, headers=headers)
        if r.status_code not in range(200, 299):  
            return {}
        return r.json()

    def search(self, query=None, operator=None, operator_query=None, search_type='artist'):
        if query == None:
            raise Exception("A query is required.")
        if isinstance(query, dict):
            query = " ".join([f"{k}:{v}" for k,v in query.items()])
        if operator != None and operator_query != None:
            if operator.lower() == "or" or operator.lower() ==  "not":
                operator = operator.upper()
                if isinstance(operator_query, str):
                    query = f"{query} {operator} {operator_query}"
        query_params = urlencode({"q": query, "type": search_type.lower()})
        print(query_params)
        return self.base_search(query_params)

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %%
spotify.search({"track": "Time", "artist": "Hans"}, search_type='track')
# Out:
# q=track%3ATime+artist%3AHans&type=track
# ,
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 170016,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB10807407'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5HTfALgK80g3MMddAKfkYd'},
#     'href': 'https://api.spotify.com/v1/tracks/5HTfALgK80g3MMddAKfkYd',
#     'id': '5HTfALgK80g3MMddAKfkYd',
#     'is_local': False,
#     'name': 'Decent Men in an Indecent Time',
#     'popularity': 22,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b720161f46e1575886389a5e784c612b94203b42?cid=18bf732ea7ab485e91a45dfe7b75d5ec',
#     'track_number': 18,
#     'type': 'track',
#     'uri': 'spotify:track:5HTfALgK80g3MMddAKfkYd'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7IdgUqOoYzcoL3DroqmWj9'},
#        'href': 'https://api.spotify.com/v1/artists/7IdgUqOoYzcoL3DroqmWj9',
#        'id': '7IdgUqOoYzcoL3DroqmWj9',
#        'name': 'Hansum',
#        'type': 'artist',
#        'uri': 'spotify:artist:7IdgUqOoYzcoL3DroqmWj9'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5MfDoYWXYdHjfEz7YFrqRP'},
#      'href': 'https://api.spotify.com/v1/albums/5MfDoYWXYdHjfEz7YFrqRP',
#      'id': '5MfDoYWXYdHjfEz7YFrqRP',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27370f04791ec10c146f12b311b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0270f04791ec10c146f12b311b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485170f04791ec10c146f12b311b',
#        'width': 64}],
#      'name': 'All The Time',
#      'release_date': '2017-07-18',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5MfDoYWXYdHjfEz7YFrqRP'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7IdgUqOoYzcoL3DroqmWj9'},
#       'href': 'https://api.spotify.com/v1/artists/7IdgUqOoYzcoL3DroqmWj9',
#       'id': '7IdgUqOoYzcoL3DroqmWj9',
#       'name': 'Hansum',
#       'type': 'artist',
#       'uri': 'spotify:artist:7IdgUqOoYzcoL3DroqmWj9'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7LrFXgUaby8e6rfohQGxhh'},
#       'href': 'https://api.spotify.com/v1/artists/7LrFXgUaby8e6rfohQGxhh',
#       'id': '7LrFXgUaby8e6rfohQGxhh',
#       'name': 'Lucas Coly',
#       'type': 'artist',
#       'uri': 'spotify:artist:7LrFXgUaby8e6rfohQGxhh'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 253368,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUYG1301018'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0EWwHAfsoZUavePMyhriGX'},
#     'href': 'https://api.spotify.com/v1/tracks/0EWwHAfsoZUavePMyhriGX',
#     'id': '0EWwHAfsoZUavePMyhriGX',
#     'is_local': False,
#     'name': 'All The Time',
#     'popularity': 14,
#     'preview_url': 'https://p.scdn.co/mp3-preview/63338619b960014de030ec1398904bf94702308b?cid=18bf732ea7ab485e91a45dfe7b75d5ec',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0EWwHAfsoZUavePMyhriGX'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0SdiiPkr02EUdekHZJkt58'},
#        'href': 'https://api.spotify.com/v1/artists/0SdiiPkr02EUdekHZJkt58',
#        'id': '0SdiiPkr02EUdekHZJkt58',
#        'name': 'Hanson',
#        'type': 'artist',
#        'uri': 'spotify:artist:0SdiiPkr02EUdekHZJkt58'}],
#      'available_markets': ['CA', 'CR', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1SNNc4pb0aA0GS2PsLr5b5'},
#      'href': 'https://api.spotify.com/v1/albums/1SNNc4pb0aA0GS2PsLr5b5',
#      'id': '1SNNc4pb0aA0GS2PsLr5b5',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273765b5b2e04bbe8443952d022',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02765b5b2e04bbe8443952d022',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851765b5b2e04bbe8443952d022',
#        'width': 64}],
#      'name': 'The Best Of Hanson 20th Century Masters The Millennium Collection',
#      'release_date': '2006-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:1SNNc4pb0aA0GS2PsLr5b5'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0SdiiPkr02EUdekHZJkt58'},
#       'href': 'https://api.spotify.com/v1/artists/0SdiiPkr02EUdekHZJkt58',
#       'id': '0SdiiPkr02EUdekHZJkt58',
#       'name': 'Hanson',
#       'type': 'artist',
#       'uri': 'spotify:artist:0SdiiPkr02EUdekHZJkt58'}],
#     'available_markets': ['CA', 'CR', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 238626,
#     'explicit': False,
#     'external_ids': {'isrc': 'USIR20000033'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7IdBM65TLaMFk3PBLlImlQ'},
#     'href': 'https://api.spotify.com/v1/tracks/7IdBM65TLaMFk3PBLlImlQ',
#     'id': '7IdBM65TLaMFk3PBLlImlQ',
#     'is_local': False,
#     'name': 'This Time Around - Radio Edit',
#     'popularity': 15,
#     'preview_url': None,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:7IdBM65TLaMFk3PBLlImlQ'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2aEKEmB4mxyvpH2KlKjFNx'},
#      'href': 'https://api.spotify.com/v1/albums/2aEKEmB4mxyvpH2KlKjFNx',
#      'id': '2aEKEmB4mxyvpH2KlKjFNx',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f31fb4f22e7bfb4cf2d0f4d2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f31fb4f22e7bfb4cf2d0f4d2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f31fb4f22e7bfb4cf2d0f4d2',
#        'width': 64}],
#      'name': 'Epic Soundtrack and Gaming Music',
#      'release_date': '2019-09-06',
#      'release_date_precision': 'day',
#      'total_tracks': 40,
#      'type': 'album',
#      'uri': 'spotify:album:2aEKEmB4mxyvpH2KlKjFNx'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YC192cP3KPCRWx8zr8MfZ'},
#       'href': 'https://api.spotify.com/v1/artists/0YC192cP3KPCRWx8zr8MfZ',
#       'id': '0YC192cP3KPCRWx8zr8MfZ',
#       'name': 'Hans Zimmer',
#       'type': 'artist',
#       'uri': 'spotify:artist:0YC192cP3KPCRWx8zr8MfZ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7i3Xc8Q0FEGHlsERoPgejc'},
#       'href': 'https://api.spotify.com/v1/artists/7i3Xc8Q0FEGHlsERoPgejc',
#       'id': '7i3Xc8Q0FEGHlsERoPgejc',
#       'name': 'Rusanda Panfili',
#       'type': 'artist',
#       'uri': 'spotify:artist:7i3Xc8Q0FEGHlsERoPgejc'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6o20t9tKjGu5c5BvluBM38'},
#       'href': 'https://api.spotify.com/v1/artists/6o20t9tKjGu5c5BvluBM38',
#       'id': '6o20t9tKjGu5c5BvluBM38',
#       'name': 'Eliane Correa',
#       'type': 'artist',
#       'uri': 'spotify:artist:6o20t9tKjGu5c5BvluBM38'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2nJZffRcm3WDa74FSkYYOb'},
#       'href': 'https://api.spotify.com/v1/artists/2nJZffRcm3WDa74FSkYYOb',
#       'id': '2nJZffRcm3WDa74FSkYYOb',
#       'name': 'Vienna Radio Symphony Orchestra',
#       'type': 'artist',
#       'uri': 'spotify:artist:2nJZffRcm3WDa74FSkYYOb'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4htujiPBxC6ynIY9V6sKOR'},
#       'href': 'https://api.spotify.com/v1/artists/4htujiPBxC6ynIY9V6sKOR',
#       'id': '4htujiPBxC6ynIY9V6sKOR',
#       'name': 'Martin Gellner',
#       'type': 'artist',
#       'uri': 'spotify:artist:4htujiPBxC6ynIY9V6sKOR'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 286493,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEE861806016'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1LHI2OuJQAxuXeOJmLM3mO'},
#     'href': 'https://api.spotify.com/v1/tracks/1LHI2OuJQAxuXeOJmLM3mO',
#     'id': '1LHI2OuJQAxuXeOJmLM3mO',
#     'is_local': False,
#     'name': 'Inception: Time - Orchestra Version - Live',
#     'popularity': 20,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f06ae5c681ff64a2b9c8f21a1d40928fef87ca74?cid=18bf732ea7ab485e91a45dfe7b75d5ec',
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:1LHI2OuJQAxuXeOJmLM3mO'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5TWpCLIhvGlbJmLK1zNpiL'},
#        'href': 'https://api.spotify.com/v1/artists/5TWpCLIhvGlbJmLK1zNpiL',
#        'id': '5TWpCLIhvGlbJmLK1zNpiL',
#        'name': 'Eric Whitacre',
#        'type': 'artist',
#        'uri': 'spotify:artist:5TWpCLIhvGlbJmLK1zNpiL'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2tPhboxrWrQ4LxOhWlXAeN'},
#        'href': 'https://api.spotify.com/v1/artists/2tPhboxrWrQ4LxOhWlXAeN',
#        'id': '2tPhboxrWrQ4LxOhWlXAeN',
#        'name': 'Eric Whitacre Singers',
#        'type': 'artist',
#        'uri': 'spotify:artist:2tPhboxrWrQ4LxOhWlXAeN'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7eZbr6Ae6X9UrZh82A6Twk'},
#        'href': 'https://api.spotify.com/v1/artists/7eZbr6Ae6X9UrZh82A6Twk',
#        'id': '7eZbr6Ae6X9UrZh82A6Twk',
#        'name': 'Marius Beck',
#        'type': 'artist',
#        'uri': 'spotify:artist:7eZbr6Ae6X9UrZh82A6Twk'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0YC192cP3KPCRWx8zr8MfZ'},
#        'href': 'https://api.spotify.com/v1/artists/0YC192cP3KPCRWx8zr8MfZ',
#        'id': '0YC192cP3KPCRWx8zr8MfZ',
#        'name': 'Hans Zimmer',
#        'type': 'artist',
#        'uri': 'spotify:artist:0YC192cP3KPCRWx8zr8MfZ'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/10BoxRpRBcGdbFropqIQlg'},
#        'href': 'https://api.spotify.com/v1/artists/10BoxRpRBcGdbFropqIQlg',
#        'id': '10BoxRpRBcGdbFropqIQlg',
#        'name': 'Hila Plitmann',
#        'type': 'artist',
#        'uri': 'spotify:artist:10BoxRpRBcGdbFropqIQlg'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/56csDAIMylI8jLs789tTUh'},
#      'href': 'https://api.spotify.com/v1/albums/56csDAIMylI8jLs789tTUh',
#      'id': '56csDAIMylI8jLs789tTUh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273de21a86cf51202eb3260eca6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02de21a86cf51202eb3260eca6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851de21a86cf51202eb3260eca6',
#        'width': 64}],
#      'name': 'Eric Whitacre Live at iTunes Festival 2014',
#      'release_date': '2015-03-23',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:56csDAIMylI8jLs789tTUh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YC192cP3KPCRWx8zr8MfZ'},
#       'href': 'https://api.spotify.com/v1/artists/0YC192cP3KPCRWx8zr8MfZ',
#       'id': '0YC192cP3KPCRWx8zr8MfZ',
#       'name': 'Hans Zimmer',
#       'type': 'artist',
#       'uri': 'spotify:artist:0YC192cP3KPCRWx8zr8MfZ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2tPhboxrWrQ4LxOhWlXAeN'},
#       'href': 'https://api.spotify.com/v1/artists/2tPhboxrWrQ4LxOhWlXAeN',
#       'id': '2tPhboxrWrQ4LxOhWlXAeN',
#       'name': 'Eric Whitacre Singers',
#       'type': 'artist',
#       'uri': 'spotify:artist:2tPhboxrWrQ4LxOhWlXAeN'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5TWpCLIhvGlbJmLK1zNpiL'},
#       'href': 'https://api.spotify.com/v1/artists/5TWpCLIhvGlbJmLK1zNpiL',
#       'id': '5TWpCLIhvGlbJmLK1zNpiL',
#       'name': 'Eric Whitacre',
#       'type': 'artist',
#       'uri': 'spotify:artist:5TWpCLIhvGlbJmLK1zNpiL'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/10BoxRpRBcGdbFropqIQlg'},
#       'href': 'https://api.spotify.com/v1/artists/10BoxRpRBcGdbFropqIQlg',
#       'id': '10BoxRpRBcGdbFropqIQlg',
#       'name': 'Hila Plitmann',
#       'type': 'artist',
#       'uri': 'spotify:artist:10BoxRpRBcGdbFropqIQlg'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 379103,
#     'explicit': False,
#     'external_ids': {'isrc': 'GB2BU1500006'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2yaDUSJxGALbLLgZ8iJlEu'},
#     'href': 'https://api.spotify.com/v1/tracks/2yaDUSJxGALbLLgZ8iJlEu',
#     'id': '2yaDUSJxGALbLLgZ8iJlEu',
#     'is_local': False,
#     'name': 'Time (feat. Hans Zimmer and Hila Plitmann) [Live at iTunes Festival 2014]',
#     'popularity': 16,
#     'preview_url': 'https://p.scdn.co/mp3-preview/947545dd179f10610efc7da668422da67b2b9cb0?cid=18bf732ea7ab485e91a45dfe7b75d5ec',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:2yaDUSJxGALbLLgZ8iJlEu'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=track%3ATime+artist%3AHans&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 853}}

# %%
# spotify.get_artist('2xiIXseIJcq3nG7C8fHeBj')

# %%
# spotify.get_album("4ZDwEvXIKxWdwhAQK8ndBU")

# %%
spotify.search(query="Danger", operator="NOT", operator_query="Zone", search_type='track')
# Out:
# q=Danger+Zone&type=track
# 138003,
#     'explicit': True,
#     'external_ids': {'isrc': 'DEQ121855131'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1p2CLrC6aBMr5EtokUqdQd'},
#     'href': 'https://api.spotify.com/v1/tracks/1p2CLrC6aBMr5EtokUqdQd',
#     'id': '1p2CLrC6aBMr5EtokUqdQd',
#     'is_local': False,
#     'name': 'Danger Zone Blues - raw',
#     'popularity': 31,
#     'preview_url': 'https://p.scdn.co/mp3-preview/475c17ad965ab01793337f622a99febe8341a989?cid=18bf732ea7ab485e91a45dfe7b75d5ec',
#     'track_number': 18,
#     'type': 'track',
#     'uri': 'spotify:track:1p2CLrC6aBMr5EtokUqdQd'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/65T6BIrUTcgylCYTXqVxvR'},
#        'href': 'https://api.spotify.com/v1/artists/65T6BIrUTcgylCYTXqVxvR',
#        'id': '65T6BIrUTcgylCYTXqVxvR',
#        'name': 'Baker Ya Maker',
#        'type': 'artist',
#        'uri': 'spotify:artist:65T6BIrUTcgylCYTXqVxvR'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5m8VnHwpH9YcAcY4TNmslX'},
#      'href': 'https://api.spotify.com/v1/albums/5m8VnHwpH9YcAcY4TNmslX',
#      'id': '5m8VnHwpH9YcAcY4TNmslX',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733f20ab26bc95e9f438d35385',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023f20ab26bc95e9f438d35385',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513f20ab26bc95e9f438d35385',
#        'width': 64}],
#      'name': 'Greates Hits, Pt. 1',
#      'release_date': '2018-10-24',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:5m8VnHwpH9YcAcY4TNmslX'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/65T6BIrUTcgylCYTXqVxvR'},
#       'href': 'https://api.spotify.com/v1/artists/65T6BIrUTcgylCYTXqVxvR',
#       'id': '65T6BIrUTcgylCYTXqVxvR',
#       'name': 'Baker Ya Maker',
#       'type': 'artist',
#       'uri': 'spotify:artist:65T6BIrUTcgylCYTXqVxvR'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 196418,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZES61801785'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2c1MoaYcylTXwG588SYh8j'},
#     'href': 'https://api.spotify.com/v1/tracks/2c1MoaYcylTXwG588SYh8j',
#     'id': '2c1MoaYcylTXwG588SYh8j',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 25,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6d127da1d92515bb8db9674c2653fe89b662e5ab?cid=18bf732ea7ab485e91a45dfe7b75d5ec',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:2c1MoaYcylTXwG588SYh8j'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0vDwx0CU6ln0giCDLK6k8D'},
#        'href': 'https://api.spotify.com/v1/artists/0vDwx0CU6ln0giCDLK6k8D',
#        'id': '0vDwx0CU6ln0giCDLK6k8D',
#        'name': 'Cherlene',
#        'type': 'artist',
#        'uri': 'spotify:artist:0vDwx0CU6ln0giCDLK6k8D'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4PIrTzsajipA45y7Uvg9X0'},
#      'href': 'https://api.spotify.com/v1/albums/4PIrTzsajipA45y7Uvg9X0',
#      'id': '4PIrTzsajipA45y7Uvg9X0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731d9a4d2294f9560c5a9b1878',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021d9a4d2294f9560c5a9b1878',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511d9a4d2294f9560c5a9b1878',
#        'width': 64}],
#      'name': 'Archer: Cherlene (Songs from the TV Series)',
#      'release_date': '2014-01-13',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:4PIrTzsajipA45y7Uvg9X0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0vDwx0CU6ln0giCDLK6k8D'},
#       'href': 'https://api.spotify.com/v1/artists/0vDwx0CU6ln0giCDLK6k8D',
#       'id': '0vDwx0CU6ln0giCDLK6k8D',
#       'name': 'Cherlene',
#       'type': 'artist',
#       'uri': 'spotify:artist:0vDwx0CU6ln0giCDLK6k8D'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Y3xIwWyq5wnNHPp5gPjOW'},
#       'href': 'https://api.spotify.com/v1/artists/3Y3xIwWyq5wnNHPp5gPjOW',
#       'id': '3Y3xIwWyq5wnNHPp5gPjOW',
#       'name': 'Kenny Loggins',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Y3xIwWyq5wnNHPp5gPjOW'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 221189,
#     'explicit': False,
#     'external_ids': {'isrc': 'USFM91400002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/50J6XwEbkYxNb5e4k6R9s1'},
#     'href': 'https://api.spotify.com/v1/tracks/50J6XwEbkYxNb5e4k6R9s1',
#     'id': '50J6XwEbkYxNb5e4k6R9s1',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 29,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:50J6XwEbkYxNb5e4k6R9s1'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/75qfbB5WRdhNF7WLZU52xW'},
#      'href': 'https://api.spotify.com/v1/albums/75qfbB5WRdhNF7WLZU52xW',
#      'id': '75qfbB5WRdhNF7WLZU52xW',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730c6ec503bd5bbc6608167941',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020c6ec503bd5bbc6608167941',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510c6ec503bd5bbc6608167941',
#        'width': 64}],
#      'name': 'Danger Zone',
#      'release_date': '2007-06-26',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:75qfbB5WRdhNF7WLZU52xW'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1DisOtNFBsfGAuifnt4o8j'},
#       'href': 'https://api.spotify.com/v1/artists/1DisOtNFBsfGAuifnt4o8j',
#       'id': '1DisOtNFBsfGAuifnt4o8j',
#       'name': 'Chino Grande',
#       'type': 'artist',
#       'uri': 'spotify:artist:1DisOtNFBsfGAuifnt4o8j'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4a8TMzvDnszW2iJbqjXvcr'},
#       'href': 'https://api.spotify.com/v1/artists/4a8TMzvDnszW2iJbqjXvcr',
#       'id': '4a8TMzvDnszW2iJbqjXvcr',
#       'name': 'Travie',
#       'type': 'artist',
#       'uri': 'spotify:artist:4a8TMzvDnszW2iJbqjXvcr'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4Byc3x9CcT699ZmORPccck'},
#       'href': 'https://api.spotify.com/v1/artists/4Byc3x9CcT699ZmORPccck',
#       'id': '4Byc3x9CcT699ZmORPccck',
#       'name': 'Midget Loco',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Byc3x9CcT699ZmORPccck'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4wMWhQQx82agVd7osP1hRT'},
#       'href': 'https://api.spotify.com/v1/artists/4wMWhQQx82agVd7osP1hRT',
#       'id': '4wMWhQQx82agVd7osP1hRT',
#       'name': 'Trouble of Brown Side',
#       'type': 'artist',
#       'uri': 'spotify:artist:4wMWhQQx82agVd7osP1hRT'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7sgVAztHMVXGT4XiczZb6F'},
#       'href': 'https://api.spotify.com/v1/artists/7sgVAztHMVXGT4XiczZb6F',
#       'id': '7sgVAztHMVXGT4XiczZb6F',
#       'name': 'Baby Jokes',
#       'type': 'artist',
#       'uri': 'spotify:artist:7sgVAztHMVXGT4XiczZb6F'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2MSULrgm9zdQfT93lgw4cE'},
#       'href': 'https://api.spotify.com/v1/artists/2MSULrgm9zdQfT93lgw4cE',
#       'id': '2MSULrgm9zdQfT93lgw4cE',
#       'name': 'Lil Tripper',
#       'type': 'artist',
#       'uri': 'spotify:artist:2MSULrgm9zdQfT93lgw4cE'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 290546,
#     'explicit': True,
#     'external_ids': {'isrc': 'USPRZ0810308'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4EeCMt2dbO1GOU19sEAJsf'},
#     'href': 'https://api.spotify.com/v1/tracks/4EeCMt2dbO1GOU19sEAJsf',
#     'id': '4EeCMt2dbO1GOU19sEAJsf',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 21,
#     'preview_url': 'https://p.scdn.co/mp3-preview/de28f48e491c98bea3b99c7d11fc2a09abc15107?cid=18bf732ea7ab485e91a45dfe7b75d5ec',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:4EeCMt2dbO1GOU19sEAJsf'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6AEIKVwB27miPI3uJxM4Dw'},
#        'href': 'https://api.spotify.com/v1/artists/6AEIKVwB27miPI3uJxM4Dw',
#        'id': '6AEIKVwB27miPI3uJxM4Dw',
#        'name': "Pickin' On Series",
#        'type': 'artist',
#        'uri': 'spotify:artist:6AEIKVwB27miPI3uJxM4Dw'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5v11gs2O8Qu8HZcrJTnWQw'},
#      'href': 'https://api.spotify.com/v1/albums/5v11gs2O8Qu8HZcrJTnWQw',
#      'id': '5v11gs2O8Qu8HZcrJTnWQw',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731fee48a28ec11f4e3ba717aa',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021fee48a28ec11f4e3ba717aa',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511fee48a28ec11f4e3ba717aa',
#        'width': 64}],
#      'name': "Pickin' On the Biggest Hits of the 1980s Vol. 2",
#      'release_date': '2017-02-24',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:5v11gs2O8Qu8HZcrJTnWQw'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6AEIKVwB27miPI3uJxM4Dw'},
#       'href': 'https://api.spotify.com/v1/artists/6AEIKVwB27miPI3uJxM4Dw',
#       'id': '6AEIKVwB27miPI3uJxM4Dw',
#       'name': "Pickin' On Series",
#       'type': 'artist',
#       'uri': 'spotify:artist:6AEIKVwB27miPI3uJxM4Dw'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/28yx4Aq8882xd1AivwMZLB'},
#       'href': 'https://api.spotify.com/v1/artists/28yx4Aq8882xd1AivwMZLB',
#       'id': '28yx4Aq8882xd1AivwMZLB',
#       'name': 'Brad Davis',
#       'type': 'artist',
#       'uri': 'spotify:artist:28yx4Aq8882xd1AivwMZLB'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 216053,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEWC1690143'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3JzOVXsaT5tTSxy28Tehpn'},
#     'href': 'https://api.spotify.com/v1/tracks/3JzOVXsaT5tTSxy28Tehpn',
#     'id': '3JzOVXsaT5tTSxy28Tehpn',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 21,
#     'preview_url': 'https://p.scdn.co/mp3-preview/87fc3dbb3710b27eed8a83e6e2dc25f4bc24d007?cid=18bf732ea7ab485e91a45dfe7b75d5ec',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:3JzOVXsaT5tTSxy28Tehpn'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=Danger+Zone&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 3083}}

# %%
spotify.search(query="Danger Zone", search_type='track')
# Out:
# q=Danger+Zone&type=track
# 138003,
#     'explicit': True,
#     'external_ids': {'isrc': 'DEQ121855131'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1p2CLrC6aBMr5EtokUqdQd'},
#     'href': 'https://api.spotify.com/v1/tracks/1p2CLrC6aBMr5EtokUqdQd',
#     'id': '1p2CLrC6aBMr5EtokUqdQd',
#     'is_local': False,
#     'name': 'Danger Zone Blues - raw',
#     'popularity': 31,
#     'preview_url': 'https://p.scdn.co/mp3-preview/475c17ad965ab01793337f622a99febe8341a989?cid=18bf732ea7ab485e91a45dfe7b75d5ec',
#     'track_number': 18,
#     'type': 'track',
#     'uri': 'spotify:track:1p2CLrC6aBMr5EtokUqdQd'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/65T6BIrUTcgylCYTXqVxvR'},
#        'href': 'https://api.spotify.com/v1/artists/65T6BIrUTcgylCYTXqVxvR',
#        'id': '65T6BIrUTcgylCYTXqVxvR',
#        'name': 'Baker Ya Maker',
#        'type': 'artist',
#        'uri': 'spotify:artist:65T6BIrUTcgylCYTXqVxvR'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5m8VnHwpH9YcAcY4TNmslX'},
#      'href': 'https://api.spotify.com/v1/albums/5m8VnHwpH9YcAcY4TNmslX',
#      'id': '5m8VnHwpH9YcAcY4TNmslX',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733f20ab26bc95e9f438d35385',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023f20ab26bc95e9f438d35385',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513f20ab26bc95e9f438d35385',
#        'width': 64}],
#      'name': 'Greates Hits, Pt. 1',
#      'release_date': '2018-10-24',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:5m8VnHwpH9YcAcY4TNmslX'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/65T6BIrUTcgylCYTXqVxvR'},
#       'href': 'https://api.spotify.com/v1/artists/65T6BIrUTcgylCYTXqVxvR',
#       'id': '65T6BIrUTcgylCYTXqVxvR',
#       'name': 'Baker Ya Maker',
#       'type': 'artist',
#       'uri': 'spotify:artist:65T6BIrUTcgylCYTXqVxvR'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 196418,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZES61801785'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2c1MoaYcylTXwG588SYh8j'},
#     'href': 'https://api.spotify.com/v1/tracks/2c1MoaYcylTXwG588SYh8j',
#     'id': '2c1MoaYcylTXwG588SYh8j',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 25,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6d127da1d92515bb8db9674c2653fe89b662e5ab?cid=18bf732ea7ab485e91a45dfe7b75d5ec',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:2c1MoaYcylTXwG588SYh8j'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0vDwx0CU6ln0giCDLK6k8D'},
#        'href': 'https://api.spotify.com/v1/artists/0vDwx0CU6ln0giCDLK6k8D',
#        'id': '0vDwx0CU6ln0giCDLK6k8D',
#        'name': 'Cherlene',
#        'type': 'artist',
#        'uri': 'spotify:artist:0vDwx0CU6ln0giCDLK6k8D'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4PIrTzsajipA45y7Uvg9X0'},
#      'href': 'https://api.spotify.com/v1/albums/4PIrTzsajipA45y7Uvg9X0',
#      'id': '4PIrTzsajipA45y7Uvg9X0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731d9a4d2294f9560c5a9b1878',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021d9a4d2294f9560c5a9b1878',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511d9a4d2294f9560c5a9b1878',
#        'width': 64}],
#      'name': 'Archer: Cherlene (Songs from the TV Series)',
#      'release_date': '2014-01-13',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:4PIrTzsajipA45y7Uvg9X0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0vDwx0CU6ln0giCDLK6k8D'},
#       'href': 'https://api.spotify.com/v1/artists/0vDwx0CU6ln0giCDLK6k8D',
#       'id': '0vDwx0CU6ln0giCDLK6k8D',
#       'name': 'Cherlene',
#       'type': 'artist',
#       'uri': 'spotify:artist:0vDwx0CU6ln0giCDLK6k8D'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Y3xIwWyq5wnNHPp5gPjOW'},
#       'href': 'https://api.spotify.com/v1/artists/3Y3xIwWyq5wnNHPp5gPjOW',
#       'id': '3Y3xIwWyq5wnNHPp5gPjOW',
#       'name': 'Kenny Loggins',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Y3xIwWyq5wnNHPp5gPjOW'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 221189,
#     'explicit': False,
#     'external_ids': {'isrc': 'USFM91400002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/50J6XwEbkYxNb5e4k6R9s1'},
#     'href': 'https://api.spotify.com/v1/tracks/50J6XwEbkYxNb5e4k6R9s1',
#     'id': '50J6XwEbkYxNb5e4k6R9s1',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 29,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:50J6XwEbkYxNb5e4k6R9s1'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/75qfbB5WRdhNF7WLZU52xW'},
#      'href': 'https://api.spotify.com/v1/albums/75qfbB5WRdhNF7WLZU52xW',
#      'id': '75qfbB5WRdhNF7WLZU52xW',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730c6ec503bd5bbc6608167941',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020c6ec503bd5bbc6608167941',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510c6ec503bd5bbc6608167941',
#        'width': 64}],
#      'name': 'Danger Zone',
#      'release_date': '2007-06-26',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:75qfbB5WRdhNF7WLZU52xW'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1DisOtNFBsfGAuifnt4o8j'},
#       'href': 'https://api.spotify.com/v1/artists/1DisOtNFBsfGAuifnt4o8j',
#       'id': '1DisOtNFBsfGAuifnt4o8j',
#       'name': 'Chino Grande',
#       'type': 'artist',
#       'uri': 'spotify:artist:1DisOtNFBsfGAuifnt4o8j'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4a8TMzvDnszW2iJbqjXvcr'},
#       'href': 'https://api.spotify.com/v1/artists/4a8TMzvDnszW2iJbqjXvcr',
#       'id': '4a8TMzvDnszW2iJbqjXvcr',
#       'name': 'Travie',
#       'type': 'artist',
#       'uri': 'spotify:artist:4a8TMzvDnszW2iJbqjXvcr'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4Byc3x9CcT699ZmORPccck'},
#       'href': 'https://api.spotify.com/v1/artists/4Byc3x9CcT699ZmORPccck',
#       'id': '4Byc3x9CcT699ZmORPccck',
#       'name': 'Midget Loco',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Byc3x9CcT699ZmORPccck'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4wMWhQQx82agVd7osP1hRT'},
#       'href': 'https://api.spotify.com/v1/artists/4wMWhQQx82agVd7osP1hRT',
#       'id': '4wMWhQQx82agVd7osP1hRT',
#       'name': 'Trouble of Brown Side',
#       'type': 'artist',
#       'uri': 'spotify:artist:4wMWhQQx82agVd7osP1hRT'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7sgVAztHMVXGT4XiczZb6F'},
#       'href': 'https://api.spotify.com/v1/artists/7sgVAztHMVXGT4XiczZb6F',
#       'id': '7sgVAztHMVXGT4XiczZb6F',
#       'name': 'Baby Jokes',
#       'type': 'artist',
#       'uri': 'spotify:artist:7sgVAztHMVXGT4XiczZb6F'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2MSULrgm9zdQfT93lgw4cE'},
#       'href': 'https://api.spotify.com/v1/artists/2MSULrgm9zdQfT93lgw4cE',
#       'id': '2MSULrgm9zdQfT93lgw4cE',
#       'name': 'Lil Tripper',
#       'type': 'artist',
#       'uri': 'spotify:artist:2MSULrgm9zdQfT93lgw4cE'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 290546,
#     'explicit': True,
#     'external_ids': {'isrc': 'USPRZ0810308'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4EeCMt2dbO1GOU19sEAJsf'},
#     'href': 'https://api.spotify.com/v1/tracks/4EeCMt2dbO1GOU19sEAJsf',
#     'id': '4EeCMt2dbO1GOU19sEAJsf',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 21,
#     'preview_url': 'https://p.scdn.co/mp3-preview/de28f48e491c98bea3b99c7d11fc2a09abc15107?cid=18bf732ea7ab485e91a45dfe7b75d5ec',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:4EeCMt2dbO1GOU19sEAJsf'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6AEIKVwB27miPI3uJxM4Dw'},
#        'href': 'https://api.spotify.com/v1/artists/6AEIKVwB27miPI3uJxM4Dw',
#        'id': '6AEIKVwB27miPI3uJxM4Dw',
#        'name': "Pickin' On Series",
#        'type': 'artist',
#        'uri': 'spotify:artist:6AEIKVwB27miPI3uJxM4Dw'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5v11gs2O8Qu8HZcrJTnWQw'},
#      'href': 'https://api.spotify.com/v1/albums/5v11gs2O8Qu8HZcrJTnWQw',
#      'id': '5v11gs2O8Qu8HZcrJTnWQw',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731fee48a28ec11f4e3ba717aa',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021fee48a28ec11f4e3ba717aa',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511fee48a28ec11f4e3ba717aa',
#        'width': 64}],
#      'name': "Pickin' On the Biggest Hits of the 1980s Vol. 2",
#      'release_date': '2017-02-24',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:5v11gs2O8Qu8HZcrJTnWQw'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6AEIKVwB27miPI3uJxM4Dw'},
#       'href': 'https://api.spotify.com/v1/artists/6AEIKVwB27miPI3uJxM4Dw',
#       'id': '6AEIKVwB27miPI3uJxM4Dw',
#       'name': "Pickin' On Series",
#       'type': 'artist',
#       'uri': 'spotify:artist:6AEIKVwB27miPI3uJxM4Dw'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/28yx4Aq8882xd1AivwMZLB'},
#       'href': 'https://api.spotify.com/v1/artists/28yx4Aq8882xd1AivwMZLB',
#       'id': '28yx4Aq8882xd1AivwMZLB',
#       'name': 'Brad Davis',
#       'type': 'artist',
#       'uri': 'spotify:artist:28yx4Aq8882xd1AivwMZLB'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 216053,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEWC1690143'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3JzOVXsaT5tTSxy28Tehpn'},
#     'href': 'https://api.spotify.com/v1/tracks/3JzOVXsaT5tTSxy28Tehpn',
#     'id': '3JzOVXsaT5tTSxy28Tehpn',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 21,
#     'preview_url': 'https://p.scdn.co/mp3-preview/87fc3dbb3710b27eed8a83e6e2dc25f4bc24d007?cid=18bf732ea7ab485e91a45dfe7b75d5ec',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:3JzOVXsaT5tTSxy28Tehpn'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=Danger+Zone&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 3083}}
